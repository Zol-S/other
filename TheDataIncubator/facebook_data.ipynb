# %% [markdown]
# # Facebook social site database
# **exploratory data analysis**<br/>
# _2019.11.03_
#
# Download data set [here](https://us8.mailchimp.com/mctx/click?url=https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fdocuments.thinknum.com%2Fdataset_dump%2Fgnhsjbgeza%2Ftemp_datalab_records_social_facebook.zip&xid=33faf01a53&uid=297)

# %%
import pandas as pd

import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %matplotlib inline

# %%
df_fb = pd.read_csv('input/temp_datalab_records_social_facebook.csv')
# Out:
# /home/zol/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_fb[:5]
# Out:
#    dataset_id                    time              username  checkins  \
# 0       53088  2015-01-01 05:00:00+00            SodaStream         0
# 1       52642  2015-01-01 05:00:00+00              ANSYSInc       148
# 2       53656  2015-01-01 05:00:00+00         MyAquaAmerica         0
# 3       53033  2015-01-01 05:00:00+00              Qualcomm       173
# 4       52783  2015-01-01 05:00:00+00  eaglepharmaceuticals         0
#
#   has_added_app  were_here_count    likes  talking_about_count  \
# 0             f                0   761533                  587
# 1             f                0    43442                 1305
# 2             f                0     5591                  297
# 3             f                0  1232521                 2685
# 4             f                0       18                    0
#
#         facebook_id date_added                   date_updated  entity_id  \
# 0       54885616308        NaN  2017-02-14 03:35:13.236826+00        NaN
# ...

# %%
print('There are {:,} records in the dataset.'.format(
    len(df_fb)
))
# Out:
# Number of records in the dataset: 3,621,391

# %%
print('There is {:,} unique usernames in the data set.'.format(
    len(df_fb['username'].unique())
))
# Out:
# There is 4,951 unique usernames in the data set.

# %%
print('There is {:,} unique Facebook IDs in the data set.'.format(
    len(df_fb['facebook_id'].unique())
))
# Out:
# There is 4,714 unique Facebook IDs in the data set.

# %%
df_fb[df_fb['facebook_id'] == 54885616308][:5]
# Out:
#       dataset_id                    time    username  checkins has_added_app  \
# 0          53088  2015-01-01 05:00:00+00  SodaStream         0             f
# 462        53088  2015-01-03 05:00:00+00  SodaStream         0             f
# 1286       53088  2015-01-04 05:00:00+00  SodaStream         0             f
# 1423       53088  2015-01-06 05:00:00+00  SodaStream         0             f
# 1868       53088  2015-01-07 05:00:00+00  SodaStream         0             f
#
#       were_here_count   likes  talking_about_count  facebook_id date_added  \
# 0                   0  761533                  587  54885616308        NaN
# 462                 0  761553                  717  54885616308        NaN
# 1286                0  761549                  735  54885616308        NaN
# 1423                0  761548                  608  54885616308        NaN
# 1868                0  761550                  608  54885616308        NaN
#
# ...

# %%
len(df_fb[df_fb['isin'].isna() == False])
# Out:
# 0

# %%
len(df_fb[df_fb['cusip'].isna() == False])
# Out:
# 0

# %%
len(df_fb[df_fb['entity_id'].isna() == False])
# Out:
# 0

# %%
len(df_fb[df_fb['date_added'].isna() == False])
# Out:
# 2099106

# %%
df_fb['has_added_app'].value_counts()
# Out:
# f    3621391
# Name: has_added_app, dtype: int64

# %%
len(df_fb[df_fb['has_added_app'].isna() == True])
# Out:
# 0

# %%
len(df_fb[df_fb['facebook_id'] == 54885616308])
# Out:
# 1221

# %%
df_fb[df_fb['were_here_count'] > 0][:5]
# Out:
#     dataset_id                    time         username  checkins  \
# 6        53146  2015-01-01 05:00:00+00          UMBBank       173
# 9        52986  2015-01-01 05:00:00+00      OfficeDepot         0
# 12       52880  2015-01-01 05:00:00+00  imagesensingsys         2
# 16       52692  2015-01-01 05:00:00+00  ChicopeeSavings         5
# 19       53502  2015-01-01 05:00:00+00       servicenow       758
#
#    has_added_app  were_here_count   likes  talking_about_count  \
# 6              f              173    6549                   58
# 9              f            46288  899982                20778
# 12             f                2      44                    1
# 16             f                5    1085                   66
# 19             f              758    4570                  184
#
#         facebook_id date_added                   date_updated  entity_id  \
# 6   211199048925162        NaN  2017-02-14 03:47:46.670674+00        NaN
# ...

# %%
df_fb['year_month'] = df_fb['time'].str[:7]

# %% [markdown]
# ## Bank sector

# %%
df_grouped_bank = df_fb[(df_fb['username'].isna() == False) & (df_fb['username'].str.lower().str.contains('bank'))][['year_month', 'likes', 'talking_about_count', 'were_here_count', 'checkins']].groupby(['year_month']).sum()

# %%
len(df_grouped_bank)
# Out:
# 43

# %%
fig = plt.gcf()
fig.set_size_inches(20, 8)

plt.plot(df_fb_grouped.index, df_fb_grouped['checkins'], 'g')
plt.plot(df_fb_grouped.index, df_fb_grouped['were_here_count'], 'r')
plt.plot(df_fb_grouped.index, df_fb_grouped['talking_about_count'], 'b')

plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)

plt.legend()
plt.savefig('output/bank.png')
plt.show()

# %% [markdown]
# ## Pharmaceutical

# %%
df_grouped_pharma = df_fb[(df_fb['username'].isna() == False) & (df_fb['username'].str.lower().str.contains('pharma'))][['year_month', 'likes', 'talking_about_count', 'were_here_count', 'checkins']].groupby(['year_month']).sum()

# %%
fig = plt.gcf()
fig.set_size_inches(20, 8)

plt.plot(df_grouped_pharma.index, df_grouped_pharma['checkins'], 'g')
plt.plot(df_grouped_pharma.index, df_grouped_pharma['were_here_count'], 'r')
plt.plot(df_grouped_pharma.index, df_grouped_pharma['talking_about_count'], 'b')

plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)

plt.legend()
plt.savefig('output/pharma.png')
plt.show()

# %% [markdown]
# ## Auto

# %%
df_grouped_auto = df_fb[(df_fb['username'].isna() == False) & (df_fb['username'].str.lower().str.contains('auto'))][['year_month', 'likes', 'talking_about_count', 'were_here_count', 'checkins']].groupby(['year_month']).sum()

# %%
fig = plt.gcf()
fig.set_size_inches(20, 8)

plt.plot(df_grouped_auto.index, df_grouped_auto['checkins'], 'g')
plt.plot(df_grouped_auto.index, df_grouped_auto['were_here_count'], 'r')
plt.plot(df_grouped_auto.index, df_grouped_auto['talking_about_count'], 'b')

plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)

plt.legend()
plt.savefig('output/auto.png')
plt.show()
